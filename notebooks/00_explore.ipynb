# %%
t = ('left', 44.44, 'temp', 99.99)

# %%
print(t[0])
# Out:
# left

# %%
print('{0:-2%}'.format(1.0/3))
# Out:
# 33.333333%

# %%
print('abcefd'.replace('cd','12'))
# Out:
# abcefd

# %%
my_string = 'whais'
for i in range(len(my_string)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(3>=3)
# Out:
# True
